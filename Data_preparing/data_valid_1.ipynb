# %%
import pandas as pd

print('Success')

# %% [markdown]
# # Vacancies part

# %% [markdown]
# ## Загрузка таблицы

# %%
data1 = pd.read_csv('datasets/IT_vacancies_full.csv', header=0)

# %%
data1
# Out:
#             Ids                                        Employer  \
# 0      49313809                                        Space307
# 1      48813842                                       Монополия
# 2      49413720                                    Eden Springs
# 3      46460892                                     Импорт Хоум
# 4      49555567                              Pride Games Studio
# ...         ...                                             ...
# 48559  49108967                                    A-N SECURITY
# 48560  49108929  Филиал ФКУ Налог-Сервис ФНС России в г. Москве
# 48561  47462568                                  Market Warrior
# 48562  48713091                                        Кон.Трол
# 48563  49108761                                     Vivid Money
#
#                                                     Name  Salary      From  \
# 0                                Golang Developer (Кипр)    True  251322.0
# 1                                      Е-mail маркетолог    True   60900.0
# 2                        Оператор call-центра (удаленно)   False       NaN
# 3                                 Ведущий SMM специалист    True   60000.0
# 4                                         UX/UI Designer   False       NaN
# ...                                                  ...     ...       ...
# 48559                       Монтажник слаботочных систем    True   60000.0
# 48560                            Системный администратор    True   60000.0
# 48561         Менеджер по работе с маркетплейсами (офис)    True   50000.0
# 48562  Менеджер по продажам (Серверное оборудование, ...    True  120000.0
# 48563                                    Product Analyst   False       NaN
#
#              To          Experience          Schedule  \
# 0           NaN       От 3 до 6 лет       Полный день
# 1           NaN  От 1 года до 3 лет       Полный день
# 2           NaN  От 1 года до 3 лет  Удаленная работа
# 3       80000.0  От 1 года до 3 лет       Полный день
# 4           NaN  От 1 года до 3 лет       Полный день
# ...         ...                 ...               ...
# 48559       NaN  От 1 года до 3 лет       Полный день
# 48560       NaN  От 1 года до 3 лет       Полный день
# 48561       NaN  От 1 года до 3 лет       Полный день
# 48562  300000.0  От 1 года до 3 лет       Полный день
# 48563       NaN       От 3 до 6 лет  Удаленная работа
#
#                                                     Keys  \
# 0      ['Docker', 'Golang', 'Redis', 'Английский язык...
# 1      ['Грамотность', 'Написание текстов', 'Грамотна...
# 2      ['Клиентоориентированность', 'Ориентация на ре...
# 3      ['Продвижение бренда', 'Креативность', 'Adobe ...
# 4      ['UI', 'UX', 'gamedev', 'game design', 'проект...
# ...                                                  ...
# 48559  ['Мобильность', 'Работа в команде', 'Системы о...
# 48560  ['Windows 7', 'Windows 8', 'Windows 10', 'Unix...
# 48561  ['Работа с большим объемом информации', 'Управ...
# 48562  ['B2B Продажи', 'Ведение переговоров', 'CRM', ...
# 48563                                            ['SQL']
#
#                                              Description             Area  \
# 0      Мы в Space307 разрабатываем международную торг...  Санкт-Петербург
# 1      С 2015 года наш IT блок меняет рынок автотранс...  Санкт-Петербург
# 2      Что нужно будет делать:  Принимать входящие зв...  Санкт-Петербург
# 3      В данный момент мы ищем в нашу команду самого ...  Санкт-Петербург
# 4      Pride Games Studio — это команда единомышленни...  Санкт-Петербург
# ...                                                  ...              ...
# 48559  Обязанности:  ведение технической документации...           Москва
# 48560  Функциональные обязанности:  Сопровождение опе...           Москва
# 48561  Мы молодая команда, занимающаяся помощью в раб...           Москва
# 48562  GAGAR&gt;IN ( ГК &quot;Con.Troll&quot; ) - рос...           Москва
# 48563  We are an innovative FinTech start-up with the...           Москва
#
#                                       Professional roles  \
# 0                           ['Программист, разработчик']
# 1                   ['Менеджер по маркетингу и рекламе']
# 2      ['Оператор call-центра, специалист контактного...
# 3                     ['SMM-менеджер, контент-менеджер']
# 4                                 ['Дизайнер, художник']
# ...                                                  ...
# 48559                     ['Сервисный инженер, механик']
# 48560                        ['Системный администратор']
# 48561                      ['Координатор отдела продаж']
# 48562  ['Менеджер по продажам, менеджер по работе с к...
# 48563                              ['Менеджер продукта']
#
#                                          Specializations  \
# 0                       ['Программирование, Разработка']
# 1                                          ['Маркетинг']
# 2      ['Маркетинг', 'Продажи по телефону, Телемаркет...
# 3      ['Управление маркетингом', 'PR, Маркетинговые ...
# 4      ['Игровое ПО', 'Программирование, Разработка',...
# ...                                                  ...
# 48559  ['Передача данных и доступ в интернет', 'Сетев...
# 48560  ['Системный администратор', 'Инженер', 'Поддер...
# 48561                           ['Управление проектами']
# 48562  ['Телекоммуникации, Сетевые решения', 'Услуги ...
# 48563  ['Менеджмент продукта (Product manager)', 'Упр...
#
#                                           Profarea names  \
# 0       ['Информационные технологии, интернет, телеком']
# 1       ['Информационные технологии, интернет, телеком']
# 2      ['Продажи', 'Информационные технологии, интерн...
# 3      ['Информационные технологии, интернет, телеком...
# 4      ['Маркетинг, реклама, PR', 'Информационные тех...
# ...                                                  ...
# 48559  ['Рабочий персонал', 'Информационные технологи...
# 48560   ['Информационные технологии, интернет, телеком']
# 48561   ['Информационные технологии, интернет, телеком']
# 48562  ['Информационные технологии, интернет, телеком...
# 48563  ['Информационные технологии, интернет, телеком...
#
#                     Published at
# 0      2021-12-02 12:15:37+03:00
# 1      2021-12-02 10:33:15+03:00
# 2      2021-12-02 10:29:37+03:00
# 3      2021-12-01 16:57:02+03:00
# 4      2021-12-01 16:48:24+03:00
# ...                          ...
# 48559  2021-10-25 11:40:23+03:00
# 48560  2021-10-25 11:39:41+03:00
# 48561  2021-10-25 11:38:52+03:00
# 48562  2021-10-25 11:38:34+03:00
# 48563  2021-10-25 11:36:59+03:00
#
# [48564 rows x 15 columns]

# %% [markdown]
# ## Первичный анализ данных

# %% [markdown]
# **Можно удалить самые неинформативные столбцы - айди и дату публикации**

# %%
data1 = data1.drop(columns=['Ids', 'Published at'])

# %% [markdown]
# ### Небольшая сводка по имеющимя данным

# %%
print('Вакансии есть в следующих городах:',
      data1['Area'].unique())
print('Представлены вакансии для специалистов со следующим уровнем работы: ',
      data1['Experience'].unique())
print('Представлены следующие возможности графика работы: ',
      data1['Schedule'].unique())
# Out:
# Вакансии есть в следующих городах: ['Санкт-Петербург' 'Москва']
# Представлены вакансии для специалистов со следующим уровнем работы:  ['От 3 до 6 лет' 'От 1 года до 3 лет' 'Нет опыта' 'Более 6 лет']
# Представлены следующие возможности графика работы:  ['Полный день' 'Удаленная работа' 'Сменный график' 'Гибкий график'
#  'Вахтовый метод']

# %%
i = 0
j = 48563
for id in data1['Salary']:
    if not id:
        i += 1
print(f'Без указания зарплаты есть {i} позиций')
print(f'C указанием зарплаты есть {j-i} позиций')
# Out:
# Без указания зарплаты есть 30982 позиций
# C указанием зарплаты есть 17581 позиций

# %%
i = 0
j = 48563
for id in data1['Schedule']:
    if (id == 'Удаленная работа'):
        i += 1
print(f'С удалёнкой есть {i} позиций')
print(f'В офисе есть {j-i} позиций')
# Out:
# С удалёнкой есть 11116 позиций
# В офисе есть 37447 позиций

# %%
i = 0
j = 48563
for id in data1['Area']:
    if (id == 'Москва'):
        i += 1
print(f'В Москве есть {i} позиций')
print(f'В Санкт-Петербурге есть {j-i} позиций')
# Out:
# В Москве есть 33775 позиций
# В Санкт-Петербурге есть 14788 позиций

# %%
print('Самые популярные навыки для поиска в процентах: ',
      data1['Keys'].value_counts(1)*100)
# Out:
# Самые популярные навыки для поиска в процентах:  Keys
# []                                                                                                                                                                                                                                                     17.092908
# ['Java']                                                                                                                                                                                                                                                0.113253
# ['Java', 'Spring Framework']                                                                                                                                                                                                                            0.080306
# ['Python']                                                                                                                                                                                                                                              0.080306
# ['SQL']                                                                                                                                                                                                                                                 0.065892
#                                                                                                                                                                                                                                                          ...
# ['Пользователь ПК', 'Техническое обслуживание', 'Монтаж оборудования', 'Работа в команде']                                                                                                                                                              0.002059
# ['Креативность', 'Управление проектами', 'Деловое общение', 'Реклама', 'Продюсирование']                                                                                                                                                                0.002059
# ['1С: Предприятие 8', '1С: Комплексная автоматизация', '1С программирование', '1С: Зарплата и управление персоналом', '1С: Управление предприятием']                                                                                                    0.002059
# ['Управление знаниями', 'Общение с клиентами', 'Оптимизация', 'Телевидение', 'Преобразование видео сигналов', 'Телевизионное производство', 'Деловая коммуникация']                                                                                     0.002059
# ['B2B Продажи', 'Ведение переговоров', 'CRM', 'Подготовка коммерческих предложений', 'Информационные технологии', 'Аналитика продаж', 'Конкурентная аналитика', 'Навыки презентации', 'Управление отношениями с клиентами', 'Деловая коммуникация']     0.002059
# Name: proportion, Length: 35371, dtype: float64

# %% [markdown]
# **У 17% вакансий не указаны требуемые навыки, это плохо, попробуем отказаться от этих вакансий**

# %%
data1 = data1.loc[data1['Keys'] != '[]']

# %% [markdown]
# **Для наглядности изобразим разброс зарплат**

# %%
print('Границы зарплат: ')
data1.hist(figsize=(15, 7.5), grid=False, sharex=True)
# Out:
# Границы зарплат:
# array([[<Axes: title={'center': 'From'}>, <Axes: title={'center': 'To'}>]],
#       dtype=object)

# %%
round(data1['From'].describe())
# Out:
# count     12751.0
# mean     109837.0
# std       72493.0
# min          43.0
# 25%       60000.0
# 50%       87000.0
# 75%      150000.0
# max      746670.0
# Name: From, dtype: float64

# %%
round(data1['To'].describe())
# Out:
# count       8561.0
# mean      162532.0
# std       108073.0
# min          100.0
# 25%        80000.0
# 50%       139200.0
# 75%       217500.0
# max      1305000.0
# Name: To, dtype: float64

# %% [markdown]
# **Теперь посмотрим, кого ищут чаще всего и сколько всего уникальных должностей у нас есть**

# %%
data1['Professional roles'].describe()
# Out:
# count                            40263
# unique                             119
# top       ['Программист, разработчик']
# freq                             13803
# Name: Professional roles, dtype: object

# %%
data1['Professional roles'].value_counts(1)*100
# Out:
# Professional roles
# ['Программист, разработчик']                                34.282095
# ['Аналитик']                                                11.809850
# ['Тестировщик']                                              5.960808
# ['Руководитель проектов']                                    4.485508
# ['Руководитель группы разработки']                           4.023545
#                                                               ...
# ['Казначей']                                                 0.002484
# ['Фотограф, ретушер']                                        0.002484
# ['Финансовый контролер']                                     0.002484
# ['Промоутер']                                                0.002484
# ['Администратор магазина, администратор торгового зала']     0.002484
# Name: proportion, Length: 119, dtype: float64

# %% [markdown]
# **Итого половина вакансий предназначена всего для трех специалистов - программиста, аналитика и тестировщика**

# %%
data1['Profarea names'].describe()
# Out:
# count                                                40263
# unique                                                1116
# top       ['Информационные технологии, интернет, телеком']
# freq                                                 28024
# Name: Profarea names, dtype: object

# %%
data1['Profarea names'].value_counts(1)*100
# Out:
# Profarea names
# ['Информационные технологии, интернет, телеком']                                                                                       69.602364
# ['Информационные технологии, интернет, телеком', 'Маркетинг, реклама, PR']                                                              2.913345
# ['Информационные технологии, интернет, телеком', 'Консультирование']                                                                    2.622755
# ['Маркетинг, реклама, PR', 'Информационные технологии, интернет, телеком']                                                              2.168244
# ['Информационные технологии, интернет, телеком', 'Продажи']                                                                             1.698830
#                                                                                                                                          ...
# ['Информационные технологии, интернет, телеком', 'Продажи', 'Консультирование', 'Безопасность']                                         0.002484
# ['Информационные технологии, интернет, телеком', 'Продажи', 'Консультирование', 'Инсталляция и сервис', 'Рабочий персонал']             0.002484
# ['Начало карьеры, студенты', 'Информационные технологии, интернет, телеком', 'Консультирование', 'Безопасность']                        0.002484
# ['Информационные технологии, интернет, телеком', 'Консультирование', 'Безопасность']                                                    0.002484
# ['Информационные технологии, интернет, телеком', 'Добыча сырья', 'Производство, сельское хозяйство', 'Строительство, недвижимость']     0.002484
# Name: proportion, Length: 1116, dtype: float64

# %% [markdown]
# **Как видно, большинство вакансий в датасете действительно из IT-компаний**

# %% [markdown]
# ### Исправим пропущенные значения

# %%
data1.isna().sum()
# Out:
# Employer                  0
# Name                      0
# Salary                    0
# From                  27512
# To                    31702
# Experience                0
# Schedule                  0
# Keys                      0
# Description               0
# Area                      0
# Professional roles        0
# Specializations           0
# Profarea names            0
# dtype: int64

# %%
data1['From'] = data1['From'].fillna("Не указана")
data1['To'] = data1['To'].fillna("Не указана")

# %%
data1
# Out:
#                                              Employer  \
# 0                                            Space307
# 1                                           Монополия
# 2                                        Eden Springs
# 3                                         Импорт Хоум
# 4                                  Pride Games Studio
# ...                                               ...
# 48559                                    A-N SECURITY
# 48560  Филиал ФКУ Налог-Сервис ФНС России в г. Москве
# 48561                                  Market Warrior
# 48562                                        Кон.Трол
# 48563                                     Vivid Money
#
#                                                     Name  Salary        From  \
# 0                                Golang Developer (Кипр)    True    251322.0
# 1                                      Е-mail маркетолог    True     60900.0
# 2                        Оператор call-центра (удаленно)   False  Не указана
# 3                                 Ведущий SMM специалист    True     60000.0
# 4                                         UX/UI Designer   False  Не указана
# ...                                                  ...     ...         ...
# 48559                       Монтажник слаботочных систем    True     60000.0
# 48560                            Системный администратор    True     60000.0
# 48561         Менеджер по работе с маркетплейсами (офис)    True     50000.0
# 48562  Менеджер по продажам (Серверное оборудование, ...    True    120000.0
# 48563                                    Product Analyst   False  Не указана
#
#                To          Experience          Schedule  \
# 0      Не указана       От 3 до 6 лет       Полный день
# 1      Не указана  От 1 года до 3 лет       Полный день
# 2      Не указана  От 1 года до 3 лет  Удаленная работа
# 3         80000.0  От 1 года до 3 лет       Полный день
# 4      Не указана  От 1 года до 3 лет       Полный день
# ...           ...                 ...               ...
# 48559  Не указана  От 1 года до 3 лет       Полный день
# 48560  Не указана  От 1 года до 3 лет       Полный день
# 48561  Не указана  От 1 года до 3 лет       Полный день
# 48562    300000.0  От 1 года до 3 лет       Полный день
# 48563  Не указана       От 3 до 6 лет  Удаленная работа
#
#                                                     Keys  \
# 0      ['Docker', 'Golang', 'Redis', 'Английский язык...
# 1      ['Грамотность', 'Написание текстов', 'Грамотна...
# 2      ['Клиентоориентированность', 'Ориентация на ре...
# 3      ['Продвижение бренда', 'Креативность', 'Adobe ...
# 4      ['UI', 'UX', 'gamedev', 'game design', 'проект...
# ...                                                  ...
# 48559  ['Мобильность', 'Работа в команде', 'Системы о...
# 48560  ['Windows 7', 'Windows 8', 'Windows 10', 'Unix...
# 48561  ['Работа с большим объемом информации', 'Управ...
# 48562  ['B2B Продажи', 'Ведение переговоров', 'CRM', ...
# 48563                                            ['SQL']
#
#                                              Description             Area  \
# 0      Мы в Space307 разрабатываем международную торг...  Санкт-Петербург
# 1      С 2015 года наш IT блок меняет рынок автотранс...  Санкт-Петербург
# 2      Что нужно будет делать:  Принимать входящие зв...  Санкт-Петербург
# 3      В данный момент мы ищем в нашу команду самого ...  Санкт-Петербург
# 4      Pride Games Studio — это команда единомышленни...  Санкт-Петербург
# ...                                                  ...              ...
# 48559  Обязанности:  ведение технической документации...           Москва
# 48560  Функциональные обязанности:  Сопровождение опе...           Москва
# 48561  Мы молодая команда, занимающаяся помощью в раб...           Москва
# 48562  GAGAR&gt;IN ( ГК &quot;Con.Troll&quot; ) - рос...           Москва
# 48563  We are an innovative FinTech start-up with the...           Москва
#
#                                       Professional roles  \
# 0                           ['Программист, разработчик']
# 1                   ['Менеджер по маркетингу и рекламе']
# 2      ['Оператор call-центра, специалист контактного...
# 3                     ['SMM-менеджер, контент-менеджер']
# 4                                 ['Дизайнер, художник']
# ...                                                  ...
# 48559                     ['Сервисный инженер, механик']
# 48560                        ['Системный администратор']
# 48561                      ['Координатор отдела продаж']
# 48562  ['Менеджер по продажам, менеджер по работе с к...
# 48563                              ['Менеджер продукта']
#
#                                          Specializations  \
# 0                       ['Программирование, Разработка']
# 1                                          ['Маркетинг']
# 2      ['Маркетинг', 'Продажи по телефону, Телемаркет...
# 3      ['Управление маркетингом', 'PR, Маркетинговые ...
# 4      ['Игровое ПО', 'Программирование, Разработка',...
# ...                                                  ...
# 48559  ['Передача данных и доступ в интернет', 'Сетев...
# 48560  ['Системный администратор', 'Инженер', 'Поддер...
# 48561                           ['Управление проектами']
# 48562  ['Телекоммуникации, Сетевые решения', 'Услуги ...
# 48563  ['Менеджмент продукта (Product manager)', 'Упр...
#
#                                           Profarea names
# 0       ['Информационные технологии, интернет, телеком']
# 1       ['Информационные технологии, интернет, телеком']
# 2      ['Продажи', 'Информационные технологии, интерн...
# 3      ['Информационные технологии, интернет, телеком...
# 4      ['Маркетинг, реклама, PR', 'Информационные тех...
# ...                                                  ...
# 48559  ['Рабочий персонал', 'Информационные технологи...
# 48560   ['Информационные технологии, интернет, телеком']
# 48561   ['Информационные технологии, интернет, телеком']
# 48562  ['Информационные технологии, интернет, телеком...
# 48563  ['Информационные технологии, интернет, телеком...
#
# [40263 rows x 13 columns]

# %% [markdown]
# ### Откажемся от работодателей, которые не указывают зарплату

# %% [markdown]
# **Но на всякий случай, сделаем это в отдельном фрейме**

# %%
data_salary = data1.loc[data1['Salary'] != False]

# %%
data_salary
# Out:
#                                              Employer  \
# 0                                            Space307
# 1                                           Монополия
# 3                                         Импорт Хоум
# 6                             Global Ports Management
# 8                                         Адверт Лайн
# ...                                               ...
# 48556                             КОНЦЕРН РТИ СИСТЕМЫ
# 48559                                    A-N SECURITY
# 48560  Филиал ФКУ Налог-Сервис ФНС России в г. Москве
# 48561                                  Market Warrior
# 48562                                        Кон.Трол
#
#                                                     Name  Salary      From  \
# 0                                Golang Developer (Кипр)    True  251322.0
# 1                                      Е-mail маркетолог    True   60900.0
# 3                                 Ведущий SMM специалист    True   60000.0
# 6                  Специалист технического сопровождения    True   47850.0
# 8                         Системный администратор/DevOps    True  160000.0
# ...                                                  ...     ...       ...
# 48556                                Инженер 2 категории    True   69600.0
# 48559                       Монтажник слаботочных систем    True   60000.0
# 48560                            Системный администратор    True   60000.0
# 48561         Менеджер по работе с маркетплейсами (офис)    True   50000.0
# 48562  Менеджер по продажам (Серверное оборудование, ...    True  120000.0
#
#                To          Experience          Schedule  \
# 0      Не указана       От 3 до 6 лет       Полный день
# 1      Не указана  От 1 года до 3 лет       Полный день
# 3         80000.0  От 1 года до 3 лет       Полный день
# 6         56550.0           Нет опыта    Сменный график
# 8      Не указана       От 3 до 6 лет  Удаленная работа
# ...           ...                 ...               ...
# 48556     87000.0       От 3 до 6 лет       Полный день
# 48559  Не указана  От 1 года до 3 лет       Полный день
# 48560  Не указана  От 1 года до 3 лет       Полный день
# 48561  Не указана  От 1 года до 3 лет       Полный день
# 48562    300000.0  От 1 года до 3 лет       Полный день
#
#                                                     Keys  \
# 0      ['Docker', 'Golang', 'Redis', 'Английский язык...
# 1      ['Грамотность', 'Написание текстов', 'Грамотна...
# 3      ['Продвижение бренда', 'Креативность', 'Adobe ...
# 6      ['Грамотная речь', 'Грамотность', 'Работа с бо...
# 8      ['devops', 'Nagios', 'Nginx', 'PHP', 'Админист...
# ...                                                  ...
# 48556  ['Работа в команде', 'MS Office', 'MS Project ...
# 48559  ['Мобильность', 'Работа в команде', 'Системы о...
# 48560  ['Windows 7', 'Windows 8', 'Windows 10', 'Unix...
# 48561  ['Работа с большим объемом информации', 'Управ...
# 48562  ['B2B Продажи', 'Ведение переговоров', 'CRM', ...
#
#                                              Description             Area  \
# 0      Мы в Space307 разрабатываем международную торг...  Санкт-Петербург
# 1      С 2015 года наш IT блок меняет рынок автотранс...  Санкт-Петербург
# 3      В данный момент мы ищем в нашу команду самого ...  Санкт-Петербург
# 6      Группа компаний «Глобал Портс» – международная...  Санкт-Петербург
# 8      Привет! Компания Advert Line объединяет в себе...  Санкт-Петербург
# ...                                                  ...              ...
# 48556  Обязанности:  Выполнение ОКР на всех этапах; Т...           Москва
# 48559  Обязанности:  ведение технической документации...           Москва
# 48560  Функциональные обязанности:  Сопровождение опе...           Москва
# 48561  Мы молодая команда, занимающаяся помощью в раб...           Москва
# 48562  GAGAR&gt;IN ( ГК &quot;Con.Troll&quot; ) - рос...           Москва
#
#                                       Professional roles  \
# 0                           ['Программист, разработчик']
# 1                   ['Менеджер по маркетингу и рекламе']
# 3                     ['SMM-менеджер, контент-менеджер']
# 6                   ['Специалист технической поддержки']
# 8                            ['Системный администратор']
# ...                                                  ...
# 48556                               ['Инженер-технолог']
# 48559                     ['Сервисный инженер, механик']
# 48560                        ['Системный администратор']
# 48561                      ['Координатор отдела продаж']
# 48562  ['Менеджер по продажам, менеджер по работе с к...
#
#                                          Specializations  \
# 0                       ['Программирование, Разработка']
# 1                                          ['Маркетинг']
# 3      ['Управление маркетингом', 'PR, Маркетинговые ...
# 6      ['Морские/Речные перевозки', 'Контейнерные пер...
# 8      ['Сетевые технологии', 'Системный администрато...
# ...                                                  ...
# 48556  ['Системная интеграция', 'Инженер', 'Радиоэлек...
# 48559  ['Передача данных и доступ в интернет', 'Сетев...
# 48560  ['Системный администратор', 'Инженер', 'Поддер...
# 48561                           ['Управление проектами']
# 48562  ['Телекоммуникации, Сетевые решения', 'Услуги ...
#
#                                           Profarea names
# 0       ['Информационные технологии, интернет, телеком']
# 1       ['Информационные технологии, интернет, телеком']
# 3      ['Информационные технологии, интернет, телеком...
# 6      ['Информационные технологии, интернет, телеком...
# 8       ['Информационные технологии, интернет, телеком']
# ...                                                  ...
# 48556  ['Информационные технологии, интернет, телеком...
# 48559  ['Рабочий персонал', 'Информационные технологи...
# 48560   ['Информационные технологии, интернет, телеком']
# 48561   ['Информационные технологии, интернет, телеком']
# 48562  ['Информационные технологии, интернет, телеком...
#
# [14570 rows x 13 columns]

# %%
data_salary = data_salary.drop(columns=['Salary'])

# %%
data_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14570 entries, 0 to 48562
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employer            14570 non-null  object
#  1   Name                14570 non-null  object
#  2   From                14570 non-null  object
#  3   To                  14570 non-null  object
#  4   Experience          14570 non-null  object
#  5   Schedule            14570 non-null  object
#  6   Keys                14570 non-null  object
#  7   Description         14570 non-null  object
#  8   Area                14570 non-null  object
#  9   Professional roles  14570 non-null  object
#  10  Specializations     14570 non-null  object
#  11  Profarea names      14570 non-null  object
# dtypes: object(12)
# memory usage: 1.4+ MB

# %% [markdown]
# **Немного видоизменим хранение навыков**

# %%
def rename_skills(row):
    return row[1:-1]

# %%
data1['Keys'] = data1['Keys'].apply(rename_skills)
data1['Professional roles'] = data1['Professional roles'].apply(rename_skills)
data1['Specializations'] = data1['Specializations'].apply(rename_skills)
data1['Profarea names'] = data1['Profarea names'].apply(rename_skills)

# %%
data1
# Out:
#                                              Employer  \
# 0                                            Space307
# 1                                           Монополия
# 2                                        Eden Springs
# 3                                         Импорт Хоум
# 4                                  Pride Games Studio
# ...                                               ...
# 48559                                    A-N SECURITY
# 48560  Филиал ФКУ Налог-Сервис ФНС России в г. Москве
# 48561                                  Market Warrior
# 48562                                        Кон.Трол
# 48563                                     Vivid Money
#
#                                                     Name  Salary        From  \
# 0                                Golang Developer (Кипр)    True    251322.0
# 1                                      Е-mail маркетолог    True     60900.0
# 2                        Оператор call-центра (удаленно)   False  Не указана
# 3                                 Ведущий SMM специалист    True     60000.0
# 4                                         UX/UI Designer   False  Не указана
# ...                                                  ...     ...         ...
# 48559                       Монтажник слаботочных систем    True     60000.0
# 48560                            Системный администратор    True     60000.0
# 48561         Менеджер по работе с маркетплейсами (офис)    True     50000.0
# 48562  Менеджер по продажам (Серверное оборудование, ...    True    120000.0
# 48563                                    Product Analyst   False  Не указана
#
#                To          Experience          Schedule  \
# 0      Не указана       От 3 до 6 лет       Полный день
# 1      Не указана  От 1 года до 3 лет       Полный день
# 2      Не указана  От 1 года до 3 лет  Удаленная работа
# 3         80000.0  От 1 года до 3 лет       Полный день
# 4      Не указана  От 1 года до 3 лет       Полный день
# ...           ...                 ...               ...
# 48559  Не указана  От 1 года до 3 лет       Полный день
# 48560  Не указана  От 1 года до 3 лет       Полный день
# 48561  Не указана  От 1 года до 3 лет       Полный день
# 48562    300000.0  От 1 года до 3 лет       Полный день
# 48563  Не указана       От 3 до 6 лет  Удаленная работа
#
#                                                     Keys  \
# 0      'Docker', 'Golang', 'Redis', 'Английский язык'...
# 1      'Грамотность', 'Написание текстов', 'Грамотная...
# 2      'Клиентоориентированность', 'Ориентация на рез...
# 3      'Продвижение бренда', 'Креативность', 'Adobe P...
# 4      'UI', 'UX', 'gamedev', 'game design', 'проекти...
# ...                                                  ...
# 48559  'Мобильность', 'Работа в команде', 'Системы ох...
# 48560  'Windows 7', 'Windows 8', 'Windows 10', 'Unix'...
# 48561  'Работа с большим объемом информации', 'Управл...
# 48562  'B2B Продажи', 'Ведение переговоров', 'CRM', '...
# 48563                                              'SQL'
#
#                                              Description             Area  \
# 0      Мы в Space307 разрабатываем международную торг...  Санкт-Петербург
# 1      С 2015 года наш IT блок меняет рынок автотранс...  Санкт-Петербург
# 2      Что нужно будет делать:  Принимать входящие зв...  Санкт-Петербург
# 3      В данный момент мы ищем в нашу команду самого ...  Санкт-Петербург
# 4      Pride Games Studio — это команда единомышленни...  Санкт-Петербург
# ...                                                  ...              ...
# 48559  Обязанности:  ведение технической документации...           Москва
# 48560  Функциональные обязанности:  Сопровождение опе...           Москва
# 48561  Мы молодая команда, занимающаяся помощью в раб...           Москва
# 48562  GAGAR&gt;IN ( ГК &quot;Con.Troll&quot; ) - рос...           Москва
# 48563  We are an innovative FinTech start-up with the...           Москва
#
#                                       Professional roles  \
# 0                             'Программист, разработчик'
# 1                     'Менеджер по маркетингу и рекламе'
# 2      'Оператор call-центра, специалист контактного ...
# 3                       'SMM-менеджер, контент-менеджер'
# 4                                   'Дизайнер, художник'
# ...                                                  ...
# 48559                       'Сервисный инженер, механик'
# 48560                          'Системный администратор'
# 48561                        'Координатор отдела продаж'
# 48562  'Менеджер по продажам, менеджер по работе с кл...
# 48563                                'Менеджер продукта'
#
#                                          Specializations  \
# 0                         'Программирование, Разработка'
# 1                                            'Маркетинг'
# 2      'Маркетинг', 'Продажи по телефону, Телемаркетинг'
# 3      'Управление маркетингом', 'PR, Маркетинговые к...
# 4      'Игровое ПО', 'Программирование, Разработка', ...
# ...                                                  ...
# 48559  'Передача данных и доступ в интернет', 'Сетевы...
# 48560  'Системный администратор', 'Инженер', 'Поддерж...
# 48561                             'Управление проектами'
# 48562  'Телекоммуникации, Сетевые решения', 'Услуги д...
# 48563  'Менеджмент продукта (Product manager)', 'Упра...
#
#                                           Profarea names
# 0         'Информационные технологии, интернет, телеком'
# 1         'Информационные технологии, интернет, телеком'
# 2      'Продажи', 'Информационные технологии, интерне...
# 3      'Информационные технологии, интернет, телеком'...
# 4      'Маркетинг, реклама, PR', 'Информационные техн...
# ...                                                  ...
# 48559  'Рабочий персонал', 'Информационные технологии...
# 48560     'Информационные технологии, интернет, телеком'
# 48561     'Информационные технологии, интернет, телеком'
# 48562  'Информационные технологии, интернет, телеком'...
# 48563  'Информационные технологии, интернет, телеком'...
#
# [40263 rows x 13 columns]

# %%
data1
# Out:
#                                              Employer  \
# 0                                            Space307
# 1                                           Монополия
# 2                                        Eden Springs
# 3                                         Импорт Хоум
# 4                                  Pride Games Studio
# ...                                               ...
# 48559                                    A-N SECURITY
# 48560  Филиал ФКУ Налог-Сервис ФНС России в г. Москве
# 48561                                  Market Warrior
# 48562                                        Кон.Трол
# 48563                                     Vivid Money
#
#                                                     Name  Salary        From  \
# 0                                Golang Developer (Кипр)    True    251322.0
# 1                                      Е-mail маркетолог    True     60900.0
# 2                        Оператор call-центра (удаленно)   False  Не указана
# 3                                 Ведущий SMM специалист    True     60000.0
# 4                                         UX/UI Designer   False  Не указана
# ...                                                  ...     ...         ...
# 48559                       Монтажник слаботочных систем    True     60000.0
# 48560                            Системный администратор    True     60000.0
# 48561         Менеджер по работе с маркетплейсами (офис)    True     50000.0
# 48562  Менеджер по продажам (Серверное оборудование, ...    True    120000.0
# 48563                                    Product Analyst   False  Не указана
#
#                To          Experience          Schedule  \
# 0      Не указана       От 3 до 6 лет       Полный день
# 1      Не указана  От 1 года до 3 лет       Полный день
# 2      Не указана  От 1 года до 3 лет  Удаленная работа
# 3         80000.0  От 1 года до 3 лет       Полный день
# 4      Не указана  От 1 года до 3 лет       Полный день
# ...           ...                 ...               ...
# 48559  Не указана  От 1 года до 3 лет       Полный день
# 48560  Не указана  От 1 года до 3 лет       Полный день
# 48561  Не указана  От 1 года до 3 лет       Полный день
# 48562    300000.0  От 1 года до 3 лет       Полный день
# 48563  Не указана       От 3 до 6 лет  Удаленная работа
#
#                                                     Keys  \
# 0      'Docker', 'Golang', 'Redis', 'Английский язык'...
# 1      'Грамотность', 'Написание текстов', 'Грамотная...
# 2      'Клиентоориентированность', 'Ориентация на рез...
# 3      'Продвижение бренда', 'Креативность', 'Adobe P...
# 4      'UI', 'UX', 'gamedev', 'game design', 'проекти...
# ...                                                  ...
# 48559  'Мобильность', 'Работа в команде', 'Системы ох...
# 48560  'Windows 7', 'Windows 8', 'Windows 10', 'Unix'...
# 48561  'Работа с большим объемом информации', 'Управл...
# 48562  'B2B Продажи', 'Ведение переговоров', 'CRM', '...
# 48563                                              'SQL'
#
#                                              Description             Area  \
# 0      Мы в Space307 разрабатываем международную торг...  Санкт-Петербург
# 1      С 2015 года наш IT блок меняет рынок автотранс...  Санкт-Петербург
# 2      Что нужно будет делать:  Принимать входящие зв...  Санкт-Петербург
# 3      В данный момент мы ищем в нашу команду самого ...  Санкт-Петербург
# 4      Pride Games Studio — это команда единомышленни...  Санкт-Петербург
# ...                                                  ...              ...
# 48559  Обязанности:  ведение технической документации...           Москва
# 48560  Функциональные обязанности:  Сопровождение опе...           Москва
# 48561  Мы молодая команда, занимающаяся помощью в раб...           Москва
# 48562  GAGAR&gt;IN ( ГК &quot;Con.Troll&quot; ) - рос...           Москва
# 48563  We are an innovative FinTech start-up with the...           Москва
#
#                                       Professional roles  \
# 0                             'Программист, разработчик'
# 1                     'Менеджер по маркетингу и рекламе'
# 2      'Оператор call-центра, специалист контактного ...
# 3                       'SMM-менеджер, контент-менеджер'
# 4                                   'Дизайнер, художник'
# ...                                                  ...
# 48559                       'Сервисный инженер, механик'
# 48560                          'Системный администратор'
# 48561                        'Координатор отдела продаж'
# 48562  'Менеджер по продажам, менеджер по работе с кл...
# 48563                                'Менеджер продукта'
#
#                                          Specializations  \
# 0                         'Программирование, Разработка'
# 1                                            'Маркетинг'
# 2      'Маркетинг', 'Продажи по телефону, Телемаркетинг'
# 3      'Управление маркетингом', 'PR, Маркетинговые к...
# 4      'Игровое ПО', 'Программирование, Разработка', ...
# ...                                                  ...
# 48559  'Передача данных и доступ в интернет', 'Сетевы...
# 48560  'Системный администратор', 'Инженер', 'Поддерж...
# 48561                             'Управление проектами'
# 48562  'Телекоммуникации, Сетевые решения', 'Услуги д...
# 48563  'Менеджмент продукта (Product manager)', 'Упра...
#
#                                           Profarea names
# 0         'Информационные технологии, интернет, телеком'
# 1         'Информационные технологии, интернет, телеком'
# 2      'Продажи', 'Информационные технологии, интерне...
# 3      'Информационные технологии, интернет, телеком'...
# 4      'Маркетинг, реклама, PR', 'Информационные техн...
# ...                                                  ...
# 48559  'Рабочий персонал', 'Информационные технологии...
# 48560     'Информационные технологии, интернет, телеком'
# 48561     'Информационные технологии, интернет, телеком'
# 48562  'Информационные технологии, интернет, телеком'...
# 48563  'Информационные технологии, интернет, телеком'...
#
# [40263 rows x 13 columns]

# %%
data_salary['Keys'][0] = data_salary['Keys'][0][1:-1]

# %%
data_salary['Keys'][0]
# Out:
# "'Docker', 'Golang', 'Redis', 'Английский язык', 'Kafka'"

# %% [markdown]
# # CV's part

# %% [markdown]
# ## Загрузка таблицы

# %%
data_cv = pd.read_csv('datasets/final_test.csv', header=0)

# %%
data_cv
# Out:
#        Unnamed: 0        id  \
# 0               0  33386754
# 1               2  36578954
# 2               3  36848494
# 3               4  36857387
# 4               5  36918449
# ...           ...       ...
# 13358       33591  39433707
# 13359       33594  39433748
# 13360       33596  39433783
# 13361       33597  39433794
# 13362       33600  39433838
#
#                                               key_skills  \
# 0      [{'name': 'SQL'}, {'name': 'JavaScript'}, {'na...
# 1      [{'name': 'Развитие ключевых клиентов'}, {'nam...
# 2                                                     []
# 3      [{'name': 'Тестирование'}, {'name': 'Тестирова...
# 4                [{'name': 'Консультирование клиентов'}]
# ...                                                  ...
# 13358   [{'name': 'Linux'}, {'name': '1С: Предприятие'}]
# 13359  [{'name': 'JavaScript'}, {'name': 'CSS'}, {'na...
# 13360  [{'name': 'jQuery'}, {'name': '1С-Битрикс'}, {...
# 13361  [{'name': 'Грамотная речь'}, {'name': 'Высокая...
# 13362  [{'name': 'XML'}, {'name': 'Функциональное тес...
#
#                                                    name  accept_temporary  \
# 0                                Аналитик-проектировщик             False
# 1            Менеджер по работе с клиентами (госсектор)             False
# 2                 Менеджер по продажам/интернет-реклама             False
# 3                          QA Engineer / Тестировщик ПО             False
# 4      Менеджер по работе с клиентами (английский язык)             False
# ...                                                 ...               ...
# 13358   Руководитель отдела IT/ системный администратор             False
# 13359                              Frontend-разработчик             False
# 13360       Веб-разработчик, frontend, html-верстальщик             False
# 13361              Специалист службы поддержки удаленно             False
# 13362        QA инженер / Специалист по тестированию ПО             False
#
#        specializations_count                       specializations_id  \
# 0                          2                             [1395, 1221]
# 1                          4                 [1292, 1270, 1246, 1295]
# 2                          5         [17333, 17242, 3209, 3148, 1225]
# 3                          2                             [1475, 1117]
# 4                          2                             [1292, 1211]
# ...                      ...                                      ...
# 13358                      4                     [994, 1273, 150, 13]
# 13359                      3                         [1475, 1221, 19]
# 13360                      5              [1172, 1221, 1744, 19, 110]
# 13361                      6  [1172, 21176, 21481, 4181, 4278, 15391]
# 13362                      1                                   [1117]
#
#                                     specializations_name  \
# 0      ['Банковское ПО', 'Программирование, Разработка']
# 1      ['Информационные технологии', 'Сетевые техноло...
# 2      ['Услуги для бизнеса', 'Прямые продажи', 'План...
# 3                         ['Игровое ПО', 'Тестирование']
# 4      ['Информационные технологии', 'Поддержка, Help...
# ...                                                  ...
# 13358  ['Информационные технологии, Интернет, Мультим...
# 13359  ['Игровое ПО', 'Программирование, Разработка',...
# 13360  ['Начальный уровень, Мало опыта', 'Программиро...
# 13361  ['Начальный уровень, Мало опыта', 'Начальный у...
# 13362                                   ['Тестирование']
#
#       specializations_profarea_id  \
# 0                             [1]
# 1                         [1, 12]
# 2                      [17, 3, 1]
# 3                             [1]
# 4                         [1, 12]
# ...                           ...
# 13358                      [9, 1]
# 13359                         [1]
# 13360                         [1]
# 13361              [1, 4, 21, 15]
# 13362                         [1]
#
#                            specializations_profarea_name  ...  \
# 0       ['Информационные технологии, интернет, телеком']  ...
# 1      ['Консультирование', 'Информационные технологи...  ...
# 2      ['Маркетинг, реклама, PR', 'Продажи', 'Информа...  ...
# 3       ['Информационные технологии, интернет, телеком']  ...
# 4      ['Консультирование', 'Информационные технологи...  ...
# ...                                                  ...  ...
# 13358  ['Высший менеджмент', 'Информационные технолог...  ...
# 13359   ['Информационные технологии, интернет, телеком']  ...
# 13360   ['Информационные технологии, интернет, телеком']  ...
# 13361  ['Транспорт, логистика', 'Начало карьеры, студ...  ...
# 13362   ['Информационные технологии, интернет, телеком']  ...
#
#       working_time_intervals_count working_time_intervals_id  \
# 0                                0                        []
# 1                                0                        []
# 2                                0                        []
# 3                                0                        []
# 4                                0                        []
# ...                            ...                       ...
# 13358                            0                        []
# 13359                            0                        []
# 13360                            0                        []
# 13361                            0                        []
# 13362                            0                        []
#
#       working_time_intervals_name working_time_modes_count  \
# 0                              []                        0
# 1                              []                        0
# 2                              []                        0
# 3                              []                        0
# 4                              []                        0
# ...                           ...                      ...
# 13358                          []                        0
# 13359                          []                        0
# 13360                          []                        0
# 13361                          []                        0
# 13362                          []                        0
#
#       working_time_modes_id working_time_modes_name  salary_from salary_to  \
# 0                        []                      []          NaN   60000.0
# 1                        []                      []          NaN   60000.0
# 2                        []                      []      50000.0   80000.0
# 3                        []                      []      25000.0   50000.0
# 4                        []                      []      60000.0       NaN
# ...                     ...                     ...          ...       ...
# 13358                    []                      []     180000.0       NaN
# 13359                    []                      []          NaN  150000.0
# 13360                    []                      []      30000.0   50000.0
# 13361                    []                      []      18000.0   25000.0
# 13362                    []                      []      45000.0   69000.0
#
#        currency  gross
# 0           RUR  False
# 1           RUR   True
# 2           RUR   True
# 3           RUR  False
# 4           RUR  False
# ...         ...    ...
# 13358       RUR  False
# 13359       RUR  False
# 13360       RUR  False
# 13361       RUR  False
# 13362       RUR   True
#
# [13363 rows x 31 columns]

# %% [markdown]
# ## Первичный анализ данных

# %% [markdown]
# **Имеем большое количество объективно избыточной для нашей задачи информации, удалим её**

# %%
data_cv = data_cv.drop(columns=['Unnamed: 0', 'id', 'accept_temporary',
                               'specializations_id', 'specializations_profarea_id',
                               'working_time_intervals_count', 'working_time_intervals_id',
                               'working_time_intervals_name', 'working_time_modes_id',
                               'working_time_modes_name', 'working_days_count',
                               'working_days_id', 'working_days_name',
                               'working_time_modes_count', 'area_id',
                               'experience_id', 'schedule_id', 'employment_id',
                               'currency', 'gross', 'specializations_count'])

# %%
data_cv
# Out:
#                                               key_skills  \
# 0      [{'name': 'SQL'}, {'name': 'JavaScript'}, {'na...
# 1      [{'name': 'Развитие ключевых клиентов'}, {'nam...
# 2                                                     []
# 3      [{'name': 'Тестирование'}, {'name': 'Тестирова...
# 4                [{'name': 'Консультирование клиентов'}]
# ...                                                  ...
# 13358   [{'name': 'Linux'}, {'name': '1С: Предприятие'}]
# 13359  [{'name': 'JavaScript'}, {'name': 'CSS'}, {'na...
# 13360  [{'name': 'jQuery'}, {'name': '1С-Битрикс'}, {...
# 13361  [{'name': 'Грамотная речь'}, {'name': 'Высокая...
# 13362  [{'name': 'XML'}, {'name': 'Функциональное тес...
#
#                                                    name  \
# 0                                Аналитик-проектировщик
# 1            Менеджер по работе с клиентами (госсектор)
# 2                 Менеджер по продажам/интернет-реклама
# 3                          QA Engineer / Тестировщик ПО
# 4      Менеджер по работе с клиентами (английский язык)
# ...                                                 ...
# 13358   Руководитель отдела IT/ системный администратор
# 13359                              Frontend-разработчик
# 13360       Веб-разработчик, frontend, html-верстальщик
# 13361              Специалист службы поддержки удаленно
# 13362        QA инженер / Специалист по тестированию ПО
#
#                                     specializations_name  \
# 0      ['Банковское ПО', 'Программирование, Разработка']
# 1      ['Информационные технологии', 'Сетевые техноло...
# 2      ['Услуги для бизнеса', 'Прямые продажи', 'План...
# 3                         ['Игровое ПО', 'Тестирование']
# 4      ['Информационные технологии', 'Поддержка, Help...
# ...                                                  ...
# 13358  ['Информационные технологии, Интернет, Мультим...
# 13359  ['Игровое ПО', 'Программирование, Разработка',...
# 13360  ['Начальный уровень, Мало опыта', 'Программиро...
# 13361  ['Начальный уровень, Мало опыта', 'Начальный у...
# 13362                                   ['Тестирование']
#
#                            specializations_profarea_name     experience_name  \
# 0       ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 1      ['Консультирование', 'Информационные технологи...  От 1 года до 3 лет
# 2      ['Маркетинг, реклама, PR', 'Продажи', 'Информа...  От 1 года до 3 лет
# 3       ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 4      ['Консультирование', 'Информационные технологи...  От 1 года до 3 лет
# ...                                                  ...                 ...
# 13358  ['Высший менеджмент', 'Информационные технолог...         Более 6 лет
# 13359   ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 13360   ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 13361  ['Транспорт, логистика', 'Начало карьеры, студ...           Нет опыта
# 13362   ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
#
#           schedule_name   employment_name        area_name  salary_from  \
# 0           Полный день  Полная занятость      Новосибирск          NaN
# 1           Полный день  Полная занятость           Казань          NaN
# 2           Полный день  Полная занятость           Москва      50000.0
# 3           Полный день  Полная занятость  Санкт-Петербург      25000.0
# 4        Сменный график  Полная занятость  Санкт-Петербург      60000.0
# ...                 ...               ...              ...          ...
# 13358       Полный день  Полная занятость           Москва     180000.0
# 13359  Удаленная работа  Полная занятость            Пенза          NaN
# 13360       Полный день  Полная занятость           Москва      30000.0
# 13361  Удаленная работа  Полная занятость  Нижний Новгород      18000.0
# 13362       Полный день  Полная занятость           Калуга      45000.0
#
#        salary_to
# 0        60000.0
# 1        60000.0
# 2        80000.0
# 3        50000.0
# 4            NaN
# ...          ...
# 13358        NaN
# 13359   150000.0
# 13360    50000.0
# 13361    25000.0
# 13362    69000.0
#
# [13363 rows x 10 columns]

# %%
print('Самые популярные навыки у соискателей в процентах: ',
      data_cv['key_skills'].value_counts(1)*100)
# Out:
# Самые популярные навыки у соискателей в процентах:  key_skills
# []                                                                                                                                                                                                                                                                                                                                                                                              30.053132
# [{'name': 'Холодные продажи'}, {'name': 'работа с VIP клиентами'}, {'name': 'Телефонные переговоры'}, {'name': 'Грамотная речь'}, {'name': 'Обучение и развитие'}]                                                                                                                                                                                                                               0.935419
# [{'name': 'Холодные продажи'}, {'name': 'CRM'}, {'name': 'Активные продажи'}, {'name': 'Холодные звонки'}, {'name': 'Клиентоориентированность'}]                                                                                                                                                                                                                                                 0.434034
# [{'name': 'Project management'}, {'name': 'Human Resources Development'}, {'name': 'Human Resources Management'}, {'name': 'CRM'}, {'name': 'Кадровый менеджмент'}, {'name': 'Грейдинг'}, {'name': 'Кадровая политика'}, {'name': 'Подбор персонала'}, {'name': 'Обучение и развитие'}, {'name': 'Оценка персонала'}, {'name': 'Управление командой'}, {'name': 'Антикризисное управление'}]     0.359201
# [{'name': '1С: Розница'}, {'name': '1С: Бухгалтерия'}, {'name': '1С: Предприятие 8'}, {'name': '1С программирование'}, {'name': 'Разработка технических заданий'}, {'name': '1С: Управление Торговлей'}, {'name': 'Автоматизация'}, {'name': 'Розничная торговля'}]                                                                                                                              0.276884
#                                                                                                                                                                                                                                                                                                                                                                                                   ...
# [{'name': 'Телефонные переговоры'}, {'name': 'MS Visual Studio'}, {'name': 'Пользователь ПК'}, {'name': 'Ремонт ПК'}, {'name': 'Internet'}]                                                                                                                                                                                                                                                      0.007483
# [{'name': 'JavaScript'}, {'name': 'Node.js'}]                                                                                                                                                                                                                                                                                                                                                    0.007483
# [{'name': 'Spring Framework'}, {'name': 'Java'}, {'name': 'AWS'}, {'name': 'Redis'}, {'name': 'Hibernate ORM'}, {'name': 'HTTP'}, {'name': 'REST'}, {'name': 'ActiveMQ'}, {'name': 'RabbitMQ'}, {'name': 'AWS SQS'}, {'name': 'React.JS'}, {'name': 'PostgreSQL'}, {'name': 'Code Optimization'}, {'name': 'Английский — B1 — Средний'}]                                                         0.007483
# [{'name': 'ООП'}, {'name': 'Git'}, {'name': 'Тестирование'}, {'name': 'Android'}, {'name': 'Android SDK'}, {'name': 'Java'}]                                                                                                                                                                                                                                                                     0.007483
# [{'name': 'XML'}, {'name': 'Функциональное тестирование'}, {'name': 'SQL'}, {'name': 'Git'}, {'name': 'Test case'}]                                                                                                                                                                                                                                                                              0.007483
# Name: proportion, Length: 7626, dtype: float64

# %% [markdown]
# **В 30% вакансий не указаны требуемые навыки, это плохо, попробуем отказаться от этих резюме**

# %%
data_cv = data_cv.loc[data_cv['key_skills'] != '[]']

# %%
data_cv
# Out:
#                                               key_skills  \
# 0      [{'name': 'SQL'}, {'name': 'JavaScript'}, {'na...
# 1      [{'name': 'Развитие ключевых клиентов'}, {'nam...
# 3      [{'name': 'Тестирование'}, {'name': 'Тестирова...
# 4                [{'name': 'Консультирование клиентов'}]
# 5      [{'name': 'XML'}, {'name': 'Git'}, {'name': 'S...
# ...                                                  ...
# 13358   [{'name': 'Linux'}, {'name': '1С: Предприятие'}]
# 13359  [{'name': 'JavaScript'}, {'name': 'CSS'}, {'na...
# 13360  [{'name': 'jQuery'}, {'name': '1С-Битрикс'}, {...
# 13361  [{'name': 'Грамотная речь'}, {'name': 'Высокая...
# 13362  [{'name': 'XML'}, {'name': 'Функциональное тес...
#
#                                                    name  \
# 0                                Аналитик-проектировщик
# 1            Менеджер по работе с клиентами (госсектор)
# 3                          QA Engineer / Тестировщик ПО
# 4      Менеджер по работе с клиентами (английский язык)
# 5                                    Системный аналитик
# ...                                                 ...
# 13358   Руководитель отдела IT/ системный администратор
# 13359                              Frontend-разработчик
# 13360       Веб-разработчик, frontend, html-верстальщик
# 13361              Специалист службы поддержки удаленно
# 13362        QA инженер / Специалист по тестированию ПО
#
#                                     specializations_name  \
# 0      ['Банковское ПО', 'Программирование, Разработка']
# 1      ['Информационные технологии', 'Сетевые техноло...
# 3                         ['Игровое ПО', 'Тестирование']
# 4      ['Информационные технологии', 'Поддержка, Help...
# 5                   ['Тестирование', 'Телекоммуникации']
# ...                                                  ...
# 13358  ['Информационные технологии, Интернет, Мультим...
# 13359  ['Игровое ПО', 'Программирование, Разработка',...
# 13360  ['Начальный уровень, Мало опыта', 'Программиро...
# 13361  ['Начальный уровень, Мало опыта', 'Начальный у...
# 13362                                   ['Тестирование']
#
#                            specializations_profarea_name     experience_name  \
# 0       ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 1      ['Консультирование', 'Информационные технологи...  От 1 года до 3 лет
# 3       ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 4      ['Консультирование', 'Информационные технологи...  От 1 года до 3 лет
# 5       ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# ...                                                  ...                 ...
# 13358  ['Высший менеджмент', 'Информационные технолог...         Более 6 лет
# 13359   ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 13360   ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 13361  ['Транспорт, логистика', 'Начало карьеры, студ...           Нет опыта
# 13362   ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
#
#           schedule_name   employment_name        area_name  salary_from  \
# 0           Полный день  Полная занятость      Новосибирск          NaN
# 1           Полный день  Полная занятость           Казань          NaN
# 3           Полный день  Полная занятость  Санкт-Петербург      25000.0
# 4        Сменный график  Полная занятость  Санкт-Петербург      60000.0
# 5           Полный день  Полная занятость  Санкт-Петербург     110000.0
# ...                 ...               ...              ...          ...
# 13358       Полный день  Полная занятость           Москва     180000.0
# 13359  Удаленная работа  Полная занятость            Пенза          NaN
# 13360       Полный день  Полная занятость           Москва      30000.0
# 13361  Удаленная работа  Полная занятость  Нижний Новгород      18000.0
# 13362       Полный день  Полная занятость           Калуга      45000.0
#
#        salary_to
# 0        60000.0
# 1        60000.0
# 3        50000.0
# 4            NaN
# 5            NaN
# ...          ...
# 13358        NaN
# 13359   150000.0
# 13360    50000.0
# 13361    25000.0
# 13362    69000.0
#
# [9347 rows x 10 columns]

# %%
data_cv['key_skills'][3]
# Out:
# "[{'name': 'Тестирование'}, {'name': 'Тестирование игр'}, {'name': 'GameDev'}, {'name': 'Контроль качества'}, {'name': 'Грамотность'}, {'name': 'Функциональное тестирование'}, {'name': 'Регресcионное тестирование'}, {'name': 'Тестирование пользовательского интерфейса'}]"

# %% [markdown]
# **Необходимо привести стобец *key_skills* в нормальный вид (как в датасете с резюме)**

# %%
input_string = data_cv['key_skills'][3]

# Разбор строки в структуру данных Python
skills_list = eval(input_string)

# Извлечение названий навыков и форматирование новой строки
formatted_string = ", ".join([f"'{skill['name']}'" for skill in skills_list])

# Вывод результата
print(formatted_string)
# Out:
# 'Тестирование', 'Тестирование игр', 'GameDev', 'Контроль качества', 'Грамотность', 'Функциональное тестирование', 'Регресcионное тестирование', 'Тестирование пользовательского интерфейса'

# %% [markdown]
# **Теперь используем этот алгоритм для всех значений**

# %%
def transform_skills(skill):
    skills_list = eval(skill)
    formatted_string = ", ".join([f"'{skill['name']}'" for skill in skills_list])
    return formatted_string

# %%
data_cv = data_cv.reset_index()

# %%
data_cv['key_skills'] = data_cv['key_skills'].apply(transform_skills)

# %%
data_cv['Keys_new_cv'] = data_cv['key_skills'].apply(lambda x: [skill.strip("'").strip() for skill in x.split(',')])
data1['Keys_new_vac'] = data1['Keys'].apply(lambda x: [skill.strip("'").strip() for skill in x.split(',')])
data1['Professional roles'] = data1['Professional roles'].apply(lambda x: [skill.strip("'").strip() for skill in x.split(',')])
data1['Specializations'] = data1['Specializations'].apply(lambda x: [skill.strip("'").strip() for skill in x.split(',')])
data1['Profarea names'] = data1['Profarea names'].apply(lambda x: [skill.strip("'").strip() for skill in x.split(',')])

# %%
data_cv
# Out:
#       index                                         key_skills  \
# 0         0  'SQL', 'JavaScript', 'Системный анализ', 'Бизн...
# 1         1  'Развитие ключевых клиентов', 'Деловая перепис...
# 2         3  'Тестирование', 'Тестирование игр', 'GameDev',...
# 3         4                        'Консультирование клиентов'
# 4         5               'XML', 'Git', 'SOAP', 'Linux', 'SQL'
# ...     ...                                                ...
# 9342  13358                         'Linux', '1С: Предприятие'
# 9343  13359  'JavaScript', 'CSS', 'HTML5', 'HTML', 'Sass', ...
# 9344  13360  'jQuery', '1С-Битрикс', 'CSS', 'Bootstrap', 'H...
# 9345  13361  'Грамотная речь', 'Высокая скорость печати', '...
# 9346  13362  'XML', 'Функциональное тестирование', 'SQL', '...
#
#                                                   name  \
# 0                               Аналитик-проектировщик
# 1           Менеджер по работе с клиентами (госсектор)
# 2                         QA Engineer / Тестировщик ПО
# 3     Менеджер по работе с клиентами (английский язык)
# 4                                   Системный аналитик
# ...                                                ...
# 9342   Руководитель отдела IT/ системный администратор
# 9343                              Frontend-разработчик
# 9344       Веб-разработчик, frontend, html-верстальщик
# 9345              Специалист службы поддержки удаленно
# 9346        QA инженер / Специалист по тестированию ПО
#
#                                    specializations_name  \
# 0     ['Банковское ПО', 'Программирование, Разработка']
# 1     ['Информационные технологии', 'Сетевые техноло...
# 2                        ['Игровое ПО', 'Тестирование']
# 3     ['Информационные технологии', 'Поддержка, Help...
# 4                  ['Тестирование', 'Телекоммуникации']
# ...                                                 ...
# 9342  ['Информационные технологии, Интернет, Мультим...
# 9343  ['Игровое ПО', 'Программирование, Разработка',...
# 9344  ['Начальный уровень, Мало опыта', 'Программиро...
# 9345  ['Начальный уровень, Мало опыта', 'Начальный у...
# 9346                                   ['Тестирование']
#
#                           specializations_profarea_name     experience_name  \
# 0      ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 1     ['Консультирование', 'Информационные технологи...  От 1 года до 3 лет
# 2      ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 3     ['Консультирование', 'Информационные технологи...  От 1 года до 3 лет
# 4      ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# ...                                                 ...                 ...
# 9342  ['Высший менеджмент', 'Информационные технолог...         Более 6 лет
# 9343   ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 9344   ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
# 9345  ['Транспорт, логистика', 'Начало карьеры, студ...           Нет опыта
# 9346   ['Информационные технологии, интернет, телеком']  От 1 года до 3 лет
#
#          schedule_name   employment_name        area_name  salary_from  \
# 0          Полный день  Полная занятость      Новосибирск          NaN
# 1          Полный день  Полная занятость           Казань          NaN
# 2          Полный день  Полная занятость  Санкт-Петербург      25000.0
# 3       Сменный график  Полная занятость  Санкт-Петербург      60000.0
# 4          Полный день  Полная занятость  Санкт-Петербург     110000.0
# ...                ...               ...              ...          ...
# 9342       Полный день  Полная занятость           Москва     180000.0
# 9343  Удаленная работа  Полная занятость            Пенза          NaN
# 9344       Полный день  Полная занятость           Москва      30000.0
# 9345  Удаленная работа  Полная занятость  Нижний Новгород      18000.0
# 9346       Полный день  Полная занятость           Калуга      45000.0
#
#       salary_to                                        Keys_new_cv
# 0       60000.0  [SQL, 'JavaScript, 'Системный анализ, 'Бизнес-...
# 1       60000.0  [Развитие ключевых клиентов, 'Деловая переписк...
# 2       50000.0  [Тестирование, 'Тестирование игр, 'GameDev, 'К...
# 3           NaN                        [Консультирование клиентов]
# 4           NaN                   [XML, 'Git, 'SOAP, 'Linux, 'SQL]
# ...         ...                                                ...
# 9342        NaN                          [Linux, '1С: Предприятие]
# 9343   150000.0   [JavaScript, 'CSS, 'HTML5, 'HTML, 'Sass, 'React]
# 9344    50000.0  [jQuery, '1С-Битрикс, 'CSS, 'Bootstrap, 'HTML,...
# 9345    25000.0  [Грамотная речь, 'Высокая скорость печати, 'Ко...
# 9346    69000.0  [XML, 'Функциональное тестирование, 'SQL, 'Git...
#
# [9347 rows x 12 columns]

# %%
data_cv = data_cv.drop(columns=['index'])

# %%
print(data_cv['key_skills'][0])
print(data_cv['key_skills'].dtype)
# Out:
# 'SQL', 'JavaScript', 'Системный анализ', 'Бизнес-анализ'
# object

# %% [markdown]
# **Для красоты изменим имена столбцов в формат первой таблицы**

# %%
data_cv = data_cv.rename(columns={'key_skills': 'Keys',
                                  'salary_from': 'From',
                                  'salary_to': 'To',
                                  'name': 'Name',
                                  'schedule_name': 'Schedule',
                                  'specializations_profarea_name' : 'Profarea names',
                                  'experience_name' : 'Experience',
                                  'specializations_name': 'Specializations'})

# %%
data_cv['Specializations'] = data_cv['Specializations'].apply(rename_skills)
data_cv['Profarea names'] = data_cv['Profarea names'].apply(rename_skills)

# %%
data_cv['Keys'][0]
# Out:
# "'SQL', 'JavaScript', 'Системный анализ', 'Бизнес-анализ'"

# %%
print("Вакансии:")
print(list(data1))
print("Резюме:")
print(list(data_cv))
# Out:
# Вакансии:
# ['Employer', 'Name', 'Salary', 'From', 'To', 'Experience', 'Schedule', 'Keys', 'Description', 'Area', 'Professional roles', 'Specializations', 'Profarea names', 'Keys_new_vac']
# Резюме:
# ['Keys', 'Name', 'Specializations', 'Profarea names', 'Experience', 'Schedule', 'employment_name', 'area_name', 'From', 'To', 'Keys_new_cv']

# %% [markdown]
# ## Составление новой таблицы

# %% [markdown]
# Здесь попытаемся создать итоговою таблицу, которая будет хранить в себе пары резюме-вакансии по лучшим совпадениям среди скиллов и информацию о том, насколько они совпадают.

# %%
data_cv['Keys'].apply(lambda x: [skill.strip("'").strip() for skill in x.split(',')])[0][2]
# Out:
# "'Системный анализ"

# %%
data1 = data1.reset_index()

# %%
del data1['index']
#del data1['level_0']

# %%
result_dict = {}

# Итерация по вакансиям и резюме для нахождения соответствий
result_columns = [
    'Vacancy', 'Employer', 'Vac_salary', 'Vac_salary_from', 'Vac_salary_to',
    'Vac_exp', 'Vac_schedule', 'Vac_description', 'Vac_prof_roles',
    'Vac_specializations', 'Vac_profar_names', 'Vac_keys', 'CV_keys', 'CV_name',
    'CV_specializations', 'CV_profar_names', 'CV_exp', 'CV_schedule',
    'CV_employment', 'CV_area_name', 'CV_salary_from', 'CV_salary_to',
    'Matching_Skills'
]
result = pd.DataFrame(columns=result_columns)

# Итерация по вакансиям и резюме для нахождения соответствий
for index_vacancy, row_vacancy in data1.iterrows():
    best_matching_resume_index = None
    best_matching_score = 0
    
    for index_resume, row_resume in data_cv.iterrows():
        matching_skills = len(set(row_vacancy['Keys_new_vac']).intersection(row_resume['Keys_new_cv']))

        # Если нашли лучшее сочетание, обновляем переменные
        if matching_skills * 10 > best_matching_score:
            best_matching_resume_index = index_resume
            best_matching_score = matching_skills * 10

    # Если подходящее резюме не найдено, пропускаем текущую вакансию
    if best_matching_resume_index is not None:
        # Создаем уникальный ключ для комбинации вакансии и резюме
        key = (row_vacancy['Name'], data_cv.loc[best_matching_resume_index, 'Name'])

        # Добавляем сочетание в датафрейм только если резюме еще не использовано
        if key not in zip(result['Vacancy'], result['CV_name']):
            result = pd.concat([result, pd.DataFrame({
                'Vacancy': [row_vacancy['Name']],
                'Employer': [row_vacancy['Employer']],
                'Vac_salary': [row_vacancy['Salary']],
                'Vac_salary_from': [row_vacancy['From']],
                'Vac_salary_to': [row_vacancy['To']],
                'Vac_exp': [row_vacancy['Experience']],
                'Vac_schedule': [row_vacancy['Schedule']],
                'Vac_description': [row_vacancy['Description']],
                'Vac_prof_roles': [row_vacancy['Professional roles']],
                'Vac_specializations': [row_vacancy['Specializations']],
                'Vac_profar_names': [row_vacancy['Profarea names']],
                'Vac_keys': [row_vacancy['Keys_new_vac']],
                'CV_keys': [data_cv.loc[best_matching_resume_index, 'Keys_new_cv']],
                'CV_name': [data_cv.loc[best_matching_resume_index, 'Name']],
                'CV_specializations': [data_cv.loc[best_matching_resume_index, 'Specializations']],
                'CV_profar_names': [data_cv.loc[best_matching_resume_index, 'Profarea names']],
                'CV_exp': [data_cv.loc[best_matching_resume_index, 'Experience']],
                'CV_schedule': [data_cv.loc[best_matching_resume_index, 'Schedule']],
                'CV_employment': [data_cv.loc[best_matching_resume_index, 'employment_name']],
                'CV_area_name': [data_cv.loc[best_matching_resume_index, 'area_name']],
                'CV_salary_from': [data_cv.loc[best_matching_resume_index, 'From']],
                'CV_salary_to': [data_cv.loc[best_matching_resume_index, 'To']],
                'Matching_Skills': [best_matching_score]
            })], ignore_index=True)

    print(index_vacancy)

# %%
result.to_csv('matching_results.csv', index=False)

# %%
result.to_csv('matching_results1.csv',
              encoding='utf-8',
              index=False)
