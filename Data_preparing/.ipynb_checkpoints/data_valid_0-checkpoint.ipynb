# %%
import os
import csv
import pandas as pd
import xml.parsers.expat

print('Success')
# Out:
# Success

# %% [markdown]
# ### Создание основной таблицы

# %% [markdown]
# **Чтение xml-файла весом 2гб с информацией о вакансиях и резюме**

# %%
def start_element(name, attrs):
    global current_element
    current_element = name

def end_element(name):
    global current_element
    current_element = None

def char_data(char_data):
    if current_element and current_element in new_pars:
        new_pars[current_element].append(char_data.strip())

new_pars = {
    'id': [],
    'idCompany': [],
    'idCv': [],
    'idVacancy': [],
    'candidateId': [],
    'creationDate': [],
    'dateModify': [],
    'candidate': [],
    'manager': [],
    'isNew': [],
    'responseType': [],
    'regionCode': [],
    'deleted': []
}

current_element = None

p = xml.parsers.expat.ParserCreate()
p.StartElementHandler = start_element
p.EndElementHandler = end_element
p.CharacterDataHandler = char_data

with open('datasets/otkliki.xml', 'rb') as file:
    xml_data = file.read()
    p.Parse(xml_data)

# for key, value in new_pars.items():
#     print(f'{key}: {value[:5]}')

# %% [markdown]
# **Перезапись изначального xml-файла в csv-таблицу**

# %%
csv_file_path = 'datasets/otkliki.csv'

if not os.path.exists(csv_file_path):
    with open(csv_file_path, 'w', newline='') as csv_file:
        writer = csv.writer(csv_file)

        # Запись заголовка
        header = list(new_pars.keys())
        writer.writerow(header)

        # Запись данных
        rows = zip(*[new_pars[key] for key in header])
        writer.writerows(rows)

    print(f'Data has been successfully saved to {csv_file_path}')
    
else:
    print(f'File {csv_file_path} already exists')
# Out:
# File datasets/otkliki.csv already exists

# %% [markdown]
# **Загрузка и проверка таблицы**

# %%
data0 = pd.read_csv('datasets/otkliki.csv', header=0)

# %%
data0
# Out:
#                                            id  \
# 0        61198530-c5f3-11ec-87d5-813aa7e4e138
# 1        303dc090-5b2e-11ed-b6c5-91f5d381286a
# 2        399df620-81c4-11ed-a38a-7dbf5d2a6230
# 3        2fc86bf0-6bb5-11ed-b055-bf7527b971f9
# 4        db547780-cd26-11ec-a429-839f0d9a4379
# ...                                       ...
# 1501083  c9267710-56d8-11ee-befa-295bfdef1967
# 1501084  b42bad30-56d8-11ee-8f4c-536ed1d8c06b
# 1501085  a13f9f10-56d8-11ee-b07a-4de93ed6c034
# 1501086  872fa770-6653-11ee-b496-8da138d7c1b3
# 1501087  82319cb0-9281-11ee-bd3f-29eee561bb17
#
#                                     idCompany  \
# 0                               1067799011708
# 1                               1120327016622
# 2        4cf72ae0-64ad-11ed-9f4b-17f530626801
# 3                             321574900025503
# 4                               1023202746071
# ...                                       ...
# 1501083  53908910-a7af-11ed-9023-732207d240c8
# ...

# %%
i = 0
for id in data0['candidateId']:
#for id in data0['idVacancy']:
    if (id == '06a52710-696a-11ed-a1b4-27c2a54abdc4'):
        print('true')
        print(i)
    else:
        i += 1
print(f'Пройдено {i} строк')
# Out:
# Пройдено 1501088 строк

# %%
data0.iloc[208395]
# Out:
# id              82f538d0-79d4-11ed-9dab-05dc90903fb8
# idCompany                              1172375064960
# idCv            1bf8d0f0-fcee-11ec-95dd-1b29d3b53cbb
# idVacancy       54b4f3d5-7abf-11ec-a66b-550ed7335bbe
# candidateId     8c8f31c0-763f-11e5-b25e-0163a9ae3d01
# creationDate                2022-11-03T09:33:47+0300
# dateModify                  2022-01-31T11:43:30+0300
# candidate                                    Активен
# manager                                      Активен
# isNew                                   Новый отклик
# responseType                                   Отказ
# regionCode                             7200000000000
# deleted                               Отклик активен
# Name: 208395, dtype: object

# %% [markdown]
# **Теперь выполним преобразование типа данных столбцов, содержащих информацию о времени**

# %%
print(data0['creationDate'].dtype)
print(data0['dateModify'].dtype)
# Out:
# object
# object

# %%
data0['creationDate'] = pd.to_datetime(data0['creationDate'],
                                       format='%Y-%m-%dT%H:%M:%S%z',
                                       errors='coerce',
                                       utc=True)
data0['dateModify'] = pd.to_datetime(data0['dateModify'],
                                     format='%Y-%m-%dT%H:%M:%S%z',
                                     errors='coerce',
                                     utc=True)

# %%
print(data0['creationDate'].dtype)
print(data0['dateModify'].dtype)
# Out:
# datetime64[ns, UTC]
# datetime64[ns, UTC]

# %% [markdown]
# **Теперь узнаем количество строк, в которых пропущено значение времени**

# %%
nan_rows = data0[data0.isna().any(axis=1)]
print("Rows with NaT:")
nan_rows
# Out:
# Rows with NaT:
#                                            id  \
# 14735    36b448f0-1311-11ed-a7a6-791a818bdadb
# 18831    f91bd270-460e-11ed-9f6b-7fb917d16256
# 35127    f2768120-17b7-11ed-9524-7fb917d16256
# 35128    be9e0700-e23e-11ec-a466-839f0d9a4379
# 58812    0035f650-3e47-11ed-8bf1-a7f767c3cfb3
# ...                                       ...
# 1466269  5dfda700-a348-11ec-86cb-d768660431c4
# 1467082  2a57e320-9153-11ee-a347-5b073a2fbeea
# 1467083  c0753800-26f3-11ee-bac2-25170f4ad2e1
# 1499541  6b14fea0-5393-11ee-8078-29eee561bb17
# 1499542  3f7bbbd0-5ded-11ee-a443-bb4c34bddc95
#
#                                     idCompany  \
# 14735                           1137448008389
# 18831                           1023100508342
# 35127                           1170280002859
# 35128                           1045402553261
# 58812                           1135543049730
# ...                                       ...
# 1466269                         1047833068942
# ...

# %% [markdown]
# **Отбросим лишние цифры в значениях региона**

# %%
data0['regionCode'] = data0['regionCode'].astype(str).str[:2].astype(int)
data0
# Out:
#                                            id  \
# 0        61198530-c5f3-11ec-87d5-813aa7e4e138
# 1        303dc090-5b2e-11ed-b6c5-91f5d381286a
# 2        399df620-81c4-11ed-a38a-7dbf5d2a6230
# 3        2fc86bf0-6bb5-11ed-b055-bf7527b971f9
# 4        db547780-cd26-11ec-a429-839f0d9a4379
# ...                                       ...
# 1501083  c9267710-56d8-11ee-befa-295bfdef1967
# 1501084  b42bad30-56d8-11ee-8f4c-536ed1d8c06b
# 1501085  a13f9f10-56d8-11ee-b07a-4de93ed6c034
# 1501086  872fa770-6653-11ee-b496-8da138d7c1b3
# 1501087  82319cb0-9281-11ee-bd3f-29eee561bb17
#
#                                     idCompany  \
# 0                               1067799011708
# 1                               1120327016622
# 2        4cf72ae0-64ad-11ed-9f4b-17f530626801
# 3                             321574900025503
# 4                               1023202746071
# ...                                       ...
# 1501083  53908910-a7af-11ed-9023-732207d240c8
# ...

# %%
# data0.iloc[1499542]

# %% [markdown]
# **Создание словаря с информацией о регионе**

# %%
region_dict = {
    1: 'Республика Адыгея',
    2: 'Республика Башкортостан',
    3: 'Республика Бурятия',
    4: 'Республика Алтай',
    5: 'Республика Дагестан',
    6: 'Республика Ингушетия',
    7: 'Кабардино-Балкарская Республика',
    8: 'Республика Калмыкия',
    9: 'Республика Карачаево-Черкесия',
    10: 'Республика Карелия',
    11: 'Республика Коми',
    12: 'Республика Марий Эл',
    13: 'Республика Мордовия',
    14: 'Республика Саха',
    15: 'Республика Северная Осетия',
    16: 'Республика Татарстан',
    17: 'Республика Тыва',
    18: 'Удмуртская Республика',
    22: 'Алтайский край',
    23: 'Краснодарский край',
    24: 'Красноярский край',
    25: 'Приморский край',
    26: 'Ставропольский край',
    27: 'Хабаровский край',
    28: 'Амурская область',
    29: 'Архангельская область',
    30: 'Астраханская область',
    31: 'Белгородская область',
    32: 'Брянская область',
    33: 'Владимирская область',
    34: 'Волгоградская область',
    35: 'Вологодская область',
    36: 'Воронежская область',
    37: 'Ивановская область',
    38: 'Иркутская область',
    39: 'Калининградская область',
    40: 'Калужская область',
    41: 'Камчатский край',
    42: 'Кемеровская область',
    43: 'Кировская область',
    44: 'Костромская область',
    45: 'Курганская область',
    46: 'Курская область',
    47: 'Ленинградская область',
    48: 'Липецкая область',
    49: 'Магаданская область',
    50: 'Московская область',
    51: 'Мурманская область',
    52: 'Нижегородская область',
    53: 'Новгородская область',
    54: 'Новосибирская область',
    55: 'Омская область',
    56: 'Оренбургская область',
    57: 'Орловская область',
    58: 'Пензенская область',
    59: 'Пермский край',
    60: 'Псковская область',
    61: 'Ростовская область',
    62: 'Рязанская область',
    63: 'Самарская область',
    64: 'Саратовская область',
    65: 'Сахалинская область',
    66: 'Свердловская область',
    67: 'Смоленская область',
    68: 'Тамбовская область',
    69: 'Тверская область',
    70: 'Томская область',
    71: 'Тульская область',
    72: 'Тюменская область',
    73: 'Ульяновская область',
    74: 'Челябинская область',
    75: 'Забайкальский край',
    76: 'Ярославская область',
    77: 'Москва',
    78: 'Санкт-Петербург',
    79: 'Еврейская автономная область',
    82: 'Республика Крым',
    83: 'Ненецкий автономный округ',
    86: 'Ханты-Манскийский автономный округ',
    87: 'Чукотский автономный округ',
    89: 'Ямало-Ненецкий автономный округ',
    92: 'Севастополь',
    95: 'Чеченская Республика',
}

# %%
data1 = pd.read_csv('datasets/IT_vacancies_full.csv', header=0)

# %%
data1
# Out:
#             Ids                                        Employer  \
# 0      49313809                                        Space307
# 1      48813842                                       Монополия
# 2      49413720                                    Eden Springs
# 3      46460892                                     Импорт Хоум
# 4      49555567                              Pride Games Studio
# ...         ...                                             ...
# 48559  49108967                                    A-N SECURITY
# 48560  49108929  Филиал ФКУ Налог-Сервис ФНС России в г. Москве
# 48561  47462568                                  Market Warrior
# 48562  48713091                                        Кон.Трол
# 48563  49108761                                     Vivid Money
#
#                                                     Name  Salary      From  \
# 0                                Golang Developer (Кипр)    True  251322.0
# ...

# %%
print('Вакансии есть в следующих городах:',
      str(data1['Area'].unique()))
print('Представлены вакансии для специалистов со следующим уровнем работы: ',
      data1['Experience'].unique())
print('Представлены следующие возможности графика работы: ',
      data1['Schedule'].unique())
# Out:
# Вакансии есть в следующих городах: ['Санкт-Петербург' 'Москва']
# Представлены вакансии для специалистов со следующим уровнем работы:  ['От 3 до 6 лет' 'От 1 года до 3 лет' 'Нет опыта' 'Более 6 лет']
# Представлены следующие возможности графика работы:  ['Полный день' 'Удаленная работа' 'Сменный график' 'Гибкий график'
#  'Вахтовый метод']

# %%
i = 0
j = 48563
for id in data1['Salary']:
    if not id:
        i += 1
print(f'Без указания зарплаты есть {i} позиций')
print(f'C указанием зарплаты есть {j-i} позиций')
# Out:
# Без указания зарплаты есть 30982 позиций
# C указанием зарплаты есть 17581 позиций

# %%
i = 0
j = 48563
for id in data1['Schedule']:
    if (id == 'Удаленная работа'):
        i += 1
print(f'С удалёнкой есть {i} позиций')
print(f'В офисе есть {j-i} позиций')
# Out:
# С удалёнкой есть 11116 позиций
# В офисе есть 37447 позиций

# %%
i = 0
j = 48563
for id in data1['Schedule']:
    if (id == 'Удаленная работа'):
        i += 1
print(f'С удалёнкой есть {i} позиций')
print(f'В офисе есть {j-i} позиций')
# Out:
# С удалёнкой есть 11116 позиций
# В офисе есть 37447 позиций

# %%
i = 0
j = 48563
for id in data1['Area']:
    if (id == 'Москва'):
        i += 1
print(f'В Москве есть {i} позиций')
print(f'В Санкт-Петербурге есть {j-i} позиций')
# Out:
# В Москве есть 33775 позиций
# В Санкт-Петербурге есть 14788 позиций

# %%
print(data1['Area'].unique())
# Out:
# ['Санкт-Петербург' 'Москва']
